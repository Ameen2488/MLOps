# %% [markdown]
# # Exercise: DVC Setup
#
# **Objective**: Initialize a DVC project and track a large file directly from this notebook.
#
# ---
#
# ## 1. Initialize DVC
# We will initialize DVC in the current directory.

# %%
# !dvc init --no-scm
# Note: We use --no-scm because this folder is already inside a git repo
# Out:
# Initialized DVC repository.
#
# +---------------------------------------------------------------------+
# |                                                                     |
# |        DVC has enabled anonymous aggregate usage analytics.         |
# |     Read the analytics documentation (and how to opt-out) here:     |
# |             <https://dvc.org/doc/user-guide/analytics>              |
# |                                                                     |
# +---------------------------------------------------------------------+
#
# What's next?
# ------------
# - Check out the documentation: <https://dvc.org/doc>
# - Get help and share ideas: <https://dvc.org/chat>
# - Star us on GitHub: <https://github.com/treeverse/dvc>

# %% [markdown]
# ## 2. Create Dummy Data
# Let's create a "large" CSV file.

# %%
import numpy as np
import pandas as pd

print("Generating data...")
df = pd.DataFrame(np.random.rand(1000, 100))
df.to_csv("data.csv", index=False)
print("data.csv created.")
# Out:
# Generating data...
# data.csv created.

# %% [markdown]
# ## 3. Track with DVC

# %%
# !dvc add data.csv
# Out:
# ⠋ Checking graph

# %% [markdown]
# ## 4. Verify
# Check that `data.csv.dvc` was created.

# %%
# !ls -l data.csv.dvc
# Out:
# 'ls' is not recognized as an internal or external command,
# operable program or batch file.
