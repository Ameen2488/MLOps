# %% [markdown]
# # Exercise: ONNX Conversion
#
# **Objective**: Export ResNet18 to ONNX format.
#
# ---
#
# ## 1. Load Model

# %%
import torch
import torchvision

model = torchvision.models.resnet18(pretrained=True)
model.eval()
print("Model loaded.")

# %% [markdown]
# ## 2. Create Dummy Input

# %%
dummy_input = torch.randn(1, 3, 224, 224)

# %% [markdown]
# ## 3. Export
# Save to `resnet18.onnx`.

# %%
# TODO: Export
torch.onnx.export(model, dummy_input, "resnet18.onnx", verbose=False)
print("Exported to resnet18.onnx")

# %% [markdown]
# ## 4. Verify File Size

# %%
# !ls -lh resnet18.onnx
