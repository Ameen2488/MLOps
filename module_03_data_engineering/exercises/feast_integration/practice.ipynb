# %% [markdown]
# # Exercise: Feast Integration
#
# **Objective**: Initialize a Feast Feature Store.
#
# ---
#
# ## 1. Initialize Repo
# We use the cli `feast init`.

# %%
# !pip install feast -q

# %%
# !feast init my_feature_repo

# %% [markdown]
# ## 2. Inspect Config
# Let's see what `feature_store.yaml` looks like.

# %%
# !cat my_feature_repo/feature_store.yaml
