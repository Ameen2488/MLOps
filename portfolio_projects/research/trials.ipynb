# %%
# Config box

d = {"key":"val", "key1":"val1"}

# %%
d['key1']
# Out:
# 'val1'

# %%
from box import ConfigBox

# %%
d2 = ConfigBox({"key": "val", "key1": "val1"})
print(d2.key)
# Out:
# val

# %%
type(d2)
# Out:
# box.config_box.ConfigBox

# %%
# ensure annotations

def get_prodict(x:int, y:int) -> int:
    return x + y

# %%
get_prodict(x=2, y=3)
# Out:
# 5

# %%
from ensure import ensure_annotations

# %%
get_prodict(x = 2, y ="3")
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[9], line 1
# ----> 1 get_prodict(x = 2, y ="3")
#
# Cell In[6], line 4, in get_prodict(x, y)
#       3 def get_prodict(x:int, y:int) -> int:
# ----> 4     return x + y
#
# TypeError: unsupported operand type(s) for +: 'int' and 'str'

# %%
#download data from gdrive

import gdown

# %%
url = "https://drive.google.com/file/d/1vWDeW9_Ew96WyTYgpOpQcFrHFdsSFOZj/view?usp=sharing"

# %%
file_id = url.split("/")[-2]
file_id
# Out:
# '1vWDeW9_Ew96WyTYgpOpQcFrHFdsSFOZj'

# %%
prefix = 'https://drive.google.com/uc?/export=download&id='

gdown.download(id=file_id, output = 'data_cnn_cancer.zip')
# Out:
# Downloading...
# From (original): https://drive.google.com/uc?id=1vWDeW9_Ew96WyTYgpOpQcFrHFdsSFOZj
# From (redirected): https://drive.google.com/uc?id=1vWDeW9_Ew96WyTYgpOpQcFrHFdsSFOZj&confirm=t&uuid=98701c2b-4647-4b95-a498-0de95de955e9
# To: c:\Users\asidd\Desktop\Data_science_projects\MLOps\portfolio_projects\research\data_cnn_cancer.zip
# 100%|██████████| 124M/124M [00:09<00:00, 12.9MB/s]
# 'data_cnn_cancer.zip'
