# %% [markdown]
# # Exercise: CD Pipeline YAML
#
# **Objective**: Write a step to build and push a docker image.
#
# ---
#
# ## 1. Complet the Step
# Fill in the missing fields.

# %%
# %%writefile docker_step.yaml
# ...
#     - name: Build and Push
#       uses: docker/build-push-action@v4
#       with:
#         # TODO: Enable pushing
#         # push: ...
#         # TODO: Set tag to myapp:latest
#         # tags: ...
