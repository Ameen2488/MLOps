# %% [markdown]
# # Exercise: MLflow Practice
#
# **Objective**: Log parameters and metrics using MLflow.
#
# ---
#
# ## 1. Setup Experiment

# %%
import mlflow

mlflow.set_experiment("exercise_mlflow_practice")

# %% [markdown]
# ## 2. Run Experiment
# Log `alpha=0.5` and `rmse=0.88`.

# %%
with mlflow.start_run():
    # TODO: Log params and metrics
    # mlflow.log_param(..., ...)
    pass

print("Run logged.")

# %% [markdown]
# ## 3. Verify
# Run `!mlflow ui` in a terminal (not here, as it blocks) to see the result.
