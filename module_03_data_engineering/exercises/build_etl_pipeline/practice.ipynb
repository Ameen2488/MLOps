# %% [markdown]
# # Exercise: Build ETL Pipeline
#
# **Objective**: Create a CSV -> Transform -> Parquet pipeline.
#
# ---
#
# ## 1. Create Raw Data

# %%
import pandas as pd
import numpy as np

df = pd.DataFrame({
    'age': np.random.randint(10, 80, 100),
    'income': np.random.randint(20000, 100000, 100)
})
df.to_csv("raw.csv", index=False)
print("raw.csv created.")

# %% [markdown]
# ## 2. The ETL Logic
# Task:
# 1. Read `raw.csv`.
# 2. Filter out `age < 18`.
# 3. Normalize `income` (divide by max).
# 4. Save to `cleaned.parquet`.

# %%
# TODO: Write logic here
df = pd.read_csv("raw.csv")
df = df[df['age'] >= 18]
# ...
# df.to_parquet...
