# %% [markdown]
# # Exercise: Monitoring Setup
#
# **Objective**: instrument a Python script with Prometheus counters.
#
# ---
#
# ## 1. Setup Metrics

# %%
from prometheus_client import Counter, start_http_server
import time
import random

# TODO: Define a Counter called 'my_failures_total'

# %% [markdown]
# ## 2. Simulation Loop
# Run a loop. If a random number < 0.2, increment the failure counter.

# %%
# TODO: Loop
# while True:
#    if random.random() < 0.2:
#        failure_counter.inc()
