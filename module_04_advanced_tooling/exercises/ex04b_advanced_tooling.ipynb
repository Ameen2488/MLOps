# %% [markdown]
# # Module 4b Exercises: Advanced Tooling
#
# **Objective**: Master Hydra, Typer, and PyTest.
#
# ---
#
# ## 🛠️ Setup
#
# ```bash
# pip install hydra-core typer pytest
# ```

# %% [markdown]
# ## 🧪 Part 1: The Broken Test
#
# **Scenario**: The following test is failing. Fix the code to make it pass.
# **Concept**: Floating point arithmetic.

# %%
def sum_floats(a, b):
    return a + b

def test_sum():
    result = sum_floats(0.1, 0.2)
    # BROKEN: 0.1 + 0.2 is actually 0.30000000000000004
    assert result == 0.3 
    print("Test Passed!")

try:
    test_sum()
except AssertionError:
    print("❌ Test Failed! Hint: Use pytest.approx or round()")

# Fix it below:
# import pytest
# assert result == pytest.approx(0.3)

# %% [markdown]
# ## 🐍 Part 2: Hydra Override Challenge
#
# **Task**: You have a config `training.lr=0.01`. You want to run a quick experiment with `lr=0.5` without changing the file.
# What is the CLI command?
#
# <details>
# <summary><b>🔻 Click for Answer</b></summary>
# <br>
# <code>python train.py training.lr=0.5</code>
# </details>

# %% [markdown]
# ## ⌨️ Part 3: Typer vs Argparse
#
# **Quiz**: Which feature does Typer have that Argparse lacks?
# A) Automatic Help messages
# B) Type Hint validation (e.g. `count: int` forces integer input)
# C) Subcommands
#
# <details>
# <summary><b>🔻 Click for Answer</b></summary>
# <br>
# <b>Answer: B</b>. Typer uses Python 3.6+ type hints to automatically validate input. Argparse requires manual type definition.
# </details>
